# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#MANY-VARIABLES" data-toc-modified-id="MANY-VARIABLES-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>MANY VARIABLES</a></span></li><li><span><a href="#DROP-LEVEL" data-toc-modified-id="DROP-LEVEL-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>DROP LEVEL</a></span></li></ul></div>

# %%
library(ggplot2)

# %%
# Basic scatter plot
p <- ggplot(mtcars, aes(x = wt, y = mpg)) +
  geom_point()

# %%
# 1 - Separate rows according to transmission type, am
p +
  facet_grid(am ~ .)
# Out:
# plot without title

# %%
# 2 - Separate columns according to cylinders, cyl
p +
  facet_grid(. ~ cyl)
# Out:
# plot without title

# %%
# 3 - Separate by both columns and rows 
p +
  facet_grid(am ~ cyl)
# Out:
# plot without title

# %% [markdown]
# ## MANY VARIABLES

# %%
library(RColorBrewer)
# Code to create the cyl_am col and myCol vector
mtcars$cyl_am <- paste(mtcars$cyl, mtcars$am, sep = "_")
myCol <- rbind(brewer.pal(9, "Blues")[c(3,6,8)],
               brewer.pal(9, "Reds")[c(3,6,8)])

# %%
# Map cyl_am onto col
ggplot(mtcars, aes(x = wt, y = mpg, col = cyl_am)) +
  geom_point() +
  # Add a manual colour scale
  scale_color_manual(values = myCol)
# Out:
# plot without title

# %%
# Grid facet on gear vs. vs
ggplot(mtcars, aes(x = wt, y = mpg, col = cyl_am)) +
  geom_point() +
  scale_color_manual(values = myCol) +
  facet_grid(gear ~ vs)
# Out:
# plot without title

# %%
# Also map disp to size
ggplot(mtcars, aes(x = wt, y = mpg, col = cyl_am, size = disp)) +
  geom_point() +
  scale_color_manual(values = myCol) +
  facet_grid(gear ~ vs)
# Out:
# plot without title

# %% [markdown]
# ## DROP LEVEL
# When you have a categorical variable with many levels which are not all present in each sub-group of another variable, it may be desirable to drop the unused levels.

# %%
# Basic scatter plot
p <- ggplot(msleep, aes(x = sleep_total, y = name, col = genus)) +
  geom_point()

# Execute to display plot
p + theme(legend.position = 'bottom')
# Out:
# plot without title

# %%
# Facet rows accoding to vore
p +
  facet_grid(vore ~ .) +
  theme(legend.position = 'none')
# Out:
# plot without title

# %%
# Specify scale and space arguments to free up rows
p +
  facet_grid(vore ~ ., scale = "free_y", space = "free_y") +
  theme(legend.position = 'none')
# Out:
# plot without title

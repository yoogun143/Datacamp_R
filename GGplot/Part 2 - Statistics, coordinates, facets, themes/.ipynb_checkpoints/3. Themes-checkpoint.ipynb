# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#RECTANGLES" data-toc-modified-id="RECTANGLES-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>RECTANGLES</a></span></li><li><span><a href="#LINES" data-toc-modified-id="LINES-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>LINES</a></span></li><li><span><a href="#TEXT" data-toc-modified-id="TEXT-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>TEXT</a></span></li><li><span><a href="#LEGENDS" data-toc-modified-id="LEGENDS-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>LEGENDS</a></span></li><li><span><a href="#POSITIONS" data-toc-modified-id="POSITIONS-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>POSITIONS</a></span></li><li><span><a href="#UPDATING-THEMES" data-toc-modified-id="UPDATING-THEMES-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>UPDATING THEMES</a></span></li><li><span><a href="#GGTHEMES" data-toc-modified-id="GGTHEMES-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>GGTHEMES</a></span></li></ul></div>

# %%
# Original plot
library(ggplot2)
z <- ggplot(mtcars, aes(x = wt, y = mpg, col = factor(cyl))) + geom_point() +
  facet_grid(.~cyl) +
  scale_x_continuous('Weight (lb/1000)') +
  scale_y_continuous('Miles/(US) gallon') +
  stat_smooth(method = 'lm', se = FALSE)
myPink = "#FEE0D2"
myRed = "#99000D"

z
# Out:
# plot without title

# %% [markdown]
# ## RECTANGLES

# %%
# Plot 1: change the plot background color to myPink:
z + theme(plot.background = element_rect(fill = myPink))
# Out:
# plot without title

# %%
# Plot 2: adjust the border to be a black line of size 3
z + theme(plot.background = element_rect(fill = myPink, color = "black", size = 3))
# Out:
# plot without title

# %%
# Plot 3: set panel.background, legend.key, legend.background and strip.background to element_blank()
uniform_panels <- theme(panel.background = element_blank(), 
                        legend.key = element_blank(), 
                        legend.background=element_blank(), 
                        strip.background = element_blank())

z + theme(plot.background = element_rect(fill = myPink, color = "black", size = 3)) + uniform_panels
# Out:
# plot without title

# %% [markdown]
# ## LINES

# %%
# Extend z with theme() function and axis lines
z + theme(panel.grid = element_blank(),
          axis.line = element_line(color = "red"),
          axis.ticks = element_line(color = "red"))
# Out:
# plot without title

# %% [markdown]
# ## TEXT

# %%
# Extend z with theme() function and axis text
z + theme(strip.text = element_text(size = 16, color = myRed),
          axis.title.x = element_text(color = myRed, hjust = 0, face = "italic"),
          axis.title.y = element_text(color = myRed, hjust = 0, face = "italic"),
          axis.text = element_text(color = "black"))
# Out:
# plot without title

# %% [markdown]
# ## LEGENDS

# %%
# Move legend by position
z + theme(legend.position = c(0.85, 0.85))
# Out:
# plot without title

# %%
# Change direction
z + theme(legend.direction = "horizontal")
# Out:
# plot without title

# %%
# Change location by name
z + theme(legend.position = "bottom")
# Out:
# plot without title

# %%
# Remove legend entirely
z + theme(legend.position = "none")
# Out:
# plot without title

# %% [markdown]
# ## POSITIONS

# %%
# Increase spacing between facets
library(grid)
z + theme(panel.spacing.x = unit(2, "cm"))
# Out:
# plot without title

# %%
# Add code to remove any excess plot margin space
z + theme(panel.spacing.x = unit(2, "cm"),
          plot.margin = unit(c(0,0,0,0), "cm"))
# Out:
# plot without title

# %% [markdown]
# ## UPDATING THEMES

# %%
# Theme layer saved as an object, theme_pink
theme_pink <- theme(panel.background = element_blank(),
                    legend.key = element_blank(),
                    legend.background = element_blank(),
                    strip.background = element_blank(),
                    plot.background = element_rect(fill = myPink, color = "black", size = 3),
                    panel.grid = element_blank(),
                    axis.line = element_line(color = "red"),
                    axis.ticks = element_line(color = "red"),
                    strip.text = element_text(size = 16, color = myRed),
                    axis.title.y = element_text(color = myRed, hjust = 0, face = "italic"),
                    axis.title.x = element_text(color = myRed, hjust = 0, face = "italic"),
                    axis.text = element_text(color = "black"),
                    legend.position = "none")

# %%
# 1 - Apply theme_pink to z2
z + 
  theme_pink
# Out:
# plot without title

# %%
# 2 - Update the default theme, and at the same time
# assign the old theme to the object old.
old <- theme_update(panel.background = element_blank(),
                    legend.key = element_blank(),
                    legend.background = element_blank(),
                    strip.background = element_blank(),
                    plot.background = element_rect(fill = myPink, color = "black", size = 3),
                    panel.grid = element_blank(),
                    axis.line = element_line(color = "red"),
                    axis.ticks = element_line(color = "red"),
                    strip.text = element_text(size = 16, color = myRed),
                    axis.title.y = element_text(color = myRed, hjust = 0, face = "italic"),
                    axis.title.x = element_text(color = myRed, hjust = 0, face = "italic"),
                    axis.text = element_text(color = "black"),
                    legend.position = "none")

# %%
# 3 - Display the plot z2 - new default theme used
z
# Out:
# plot without title

# %%
# 4 - Restore the old default theme
theme_set(old)

# %%
# Display the plot z2 - old theme restored
z
# Out:
# plot without title

# %% [markdown]
# ## GGTHEMES

# %%
# Load ggthemes package
library(ggthemes)

# Apply theme_tufte
z + theme_tufte()
# Out:
# Warning message:
# "package 'ggthemes' was built under R version 3.5.2"
# plot without title

# %%
# Apply theme_tufte, modified:
z + theme_tufte() + 
  theme(legend.position = c(0.9, 0.9),
        legend.title = element_text(face = "italic", size = 12),
        axis.title = element_text(face = "bold", size = 14))
# Out:
# plot without title

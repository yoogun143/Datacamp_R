# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#HEATMAP" data-toc-modified-id="HEATMAP-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>HEATMAP</a></span></li><li><span><a href="#ALTERNATIVE-1:-SCATTERPLOT" data-toc-modified-id="ALTERNATIVE-1:-SCATTERPLOT-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>ALTERNATIVE 1: SCATTERPLOT</a></span></li><li><span><a href="#ALTERNATIVE-2:-LINEPLOT" data-toc-modified-id="ALTERNATIVE-2:-LINEPLOT-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>ALTERNATIVE 2: LINEPLOT</a></span></li><li><span><a href="#DEPICT-OVERLAPPING-MEASUREMENTS-OF-SPREAD:-OVERLLAPING-TRANSPARENT-RIBBON" data-toc-modified-id="DEPICT-OVERLAPPING-MEASUREMENTS-OF-SPREAD:-OVERLLAPING-TRANSPARENT-RIBBON-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>DEPICT OVERLAPPING MEASUREMENTS OF SPREAD: OVERLLAPING TRANSPARENT RIBBON</a></span></li><li><span><a href="#DEPICT-OVERLAPPING-MEASUREMENTS-OF-SPREAD:-DODGED-ERROR-BARS" data-toc-modified-id="DEPICT-OVERLAPPING-MEASUREMENTS-OF-SPREAD:-DODGED-ERROR-BARS-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>DEPICT OVERLAPPING MEASUREMENTS OF SPREAD: DODGED ERROR BARS</a></span></li></ul></div>

# %% [markdown]
# ## HEATMAP
# - Pitfall 1: Color on a continuous scale is hard to interpret
# - Pitfall 2: Perception changes based on neighboring colors

# %%
library(ggplot2)
library(RColorBrewer)
library(lattice)
# Out:
# Warning message:
# "package 'lattice' was built under R version 3.5.2"

# %%
# Create color palette
myColors <- brewer.pal(9, "Reds")

# %%
# Build the heat map from scratch
ggplot(barley, aes(x = year, y = variety, fill = yield)) +
  geom_tile() + # Geom layer
  facet_wrap( ~ site, ncol = 1) + # Facet layer
  scale_fill_gradientn(colors = myColors) # Adjust colors
# Out:
# plot without title

# %% [markdown]
# ## ALTERNATIVE 1: SCATTERPLOT

# %%
ggplot(barley, aes(x = yield, y = variety, col = year)) +
  geom_point(pch = 1, size = 2) +
  facet_wrap( ~ site, ncol = 1)
# Out:
# plot without title

# %% [markdown]
# ## ALTERNATIVE 2: LINEPLOT

# %%
# Line plot; set the aes, geom and facet
ggplot(barley, aes(x = year, y = yield, color = variety, group = variety)) + 
  geom_line() +
  facet_wrap( ~ site, nrow = 1)
# Out:
# plot without title

# %% [markdown]
# ## DEPICT OVERLAPPING MEASUREMENTS OF SPREAD: OVERLLAPING TRANSPARENT RIBBON

# %%
# Create overlapping ribbon plot from scratch
ggplot(barley, aes(x = year, y = yield, col = site, group = site, fill = site)) +
  stat_summary(fun.y = mean, geom = "line") +
  stat_summary(fun.data = mean_sdl, fun.args = list(mult = 1), geom = "ribbon", alpha = 0.1, col = NA)
# Out:
# plot without title

# %% [markdown]
# ## DEPICT OVERLAPPING MEASUREMENTS OF SPREAD: DODGED ERROR BARS

# %%
ggplot(barley, aes(x = year, y = yield, col = site, group = site, fill = site)) +
  stat_summary(fun.y = mean, geom = "line") +
  stat_summary(fun.data = mean_sdl, fun.args = list(mult = 1), geom = "errorbar", width = 0.1) +
  coord_fixed(ratio = 0.01)
# Out:
# plot without title

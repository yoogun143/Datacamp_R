# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#BARPLOT" data-toc-modified-id="BARPLOT-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>BARPLOT</a></span></li><li><span><a href="#SCATTERPLOT" data-toc-modified-id="SCATTERPLOT-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>SCATTERPLOT</a></span></li><li><span><a href="#SCALE" data-toc-modified-id="SCALE-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>SCALE</a></span></li><li><span><a href="#DUMMY-AESTHETICS-(y-always-need-to-be-set)" data-toc-modified-id="DUMMY-AESTHETICS-(y-always-need-to-be-set)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>DUMMY AESTHETICS (y always need to be set)</a></span></li></ul></div>

# %% [markdown]
# ## BARPLOT

# %%
library(ggplot2)

# %%
# The base layer, cyl.am, is available for you
cyl.am <- ggplot(mtcars, aes(x = factor(cyl), fill = factor(am)))
# Add geom (position = "stack" by default)
cyl.am + 
  geom_bar()
# Out:
# plot without title

# %%
# Fill - show proportion
cyl.am + 
  geom_bar(position = "fill")
# Out:
# plot without title

# %%
# Dodging - principles of similarity and proximity
cyl.am +
  geom_bar(position = "dodge")
# Out:
# plot without title

# %%
# Parameter for dodge
cyl.am +
  geom_bar(position = position_dodge(0.7))
# Out:
# plot without title

# %%
# Clean up the axes with scale_ functions (Legend)
val = c("#E41A1C", "#377EB8")
lab = c("Manual", "Automatic")
cyl.am +
  geom_bar(position = "dodge") +
  scale_x_discrete("Cylinders") + 
  scale_y_continuous('Number') +
  scale_fill_manual("Transmission", 
                    values = val,
                    labels = lab)
# Out:
# plot without title

# %% [markdown]
# ## SCATTERPLOT

# %%
# Position identity (default)
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, col = Species)) +
  geom_point()
# Out:
# plot without title

# %%
# Equal to
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, col = Species)) +
  geom_point(position = 'identity')
# Out:
# plot without title

# %%
# Position jitter
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, col = Species)) +
  geom_point(position = 'jitter')
# Out:
# plot without title

# %%
# Parameter for jitter
posn.j <- position_jitter(width = 0.1)

ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, col = Species)) +
  geom_point(position = posn.j)
# Out:
# plot without title

# %% [markdown]
# ## SCALE

# %%
# Scale_
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, col = Species)) +
  geom_point(position = "jitter") +
  scale_x_continuous("Sepal Length") +
  scale_color_discrete("Species")
# Out:
# plot without title

# %%
# Limit
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, col = Species)) +
  geom_point(position = "jitter") +
  scale_x_continuous("Sepal Length", limits = c(2, 8)) +
  scale_color_discrete("Species")
# Out:
# plot without title

# %%
# Breaks
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, col = Species)) +
  geom_point(position = "jitter") +
  scale_x_continuous("Sepal Length", limits = c(2, 8), 
                     breaks = seq(2, 8, 3)) +
  scale_color_discrete("Species")
# Out:
# plot without title

# %%
# Expand
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, col = Species)) +
  geom_point(position = "jitter") +
  scale_x_continuous("Sepal Length", limits = c(2, 8), 
                     breaks = seq(2, 8, 3), expand = c(0, 0)) +
  scale_color_discrete("Species")
# Out:
# plot without title

# %%
# Label
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, col = Species)) +
  geom_point(position = "jitter") +
  scale_x_continuous("Sepal Length", limits = c(2, 8), 
                     breaks = seq(2, 8, 3), expand = c(0, 0)) +
  scale_color_discrete("Species",
                       labels = c('Setosa', "Versicolour", 'Virginica'))
# Out:
# plot without title

# %%
# Lab = Other method for label
ggplot(iris, aes(x = Sepal.Length, y = Sepal.Width, col = Species)) +
  geom_point(position = "jitter") +
  labs(x = "Sepal Length", y = "Sepal Width", col = "Species")
# Out:
# plot without title

# %% [markdown]
# ## DUMMY AESTHETICS (y always need to be set)

# %%
# 1 - Create jittered plot of mtcars, mpg onto x, 0 onto y
ggplot(mtcars, aes(x = mpg, y = 0)) +
  geom_jitter()
# Out:
# plot without title

# %%
# 2 - Add function to change y axis limits
ggplot(mtcars, aes(x = mpg, y = 0)) +
  geom_jitter() +
  scale_y_continuous(limits = c(-2,2))
# Out:
# plot without title

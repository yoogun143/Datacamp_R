# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#TRANSFORMATION-FOR-HEAVILY-SKEWED-DATA" data-toc-modified-id="TRANSFORMATION-FOR-HEAVILY-SKEWED-DATA-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>TRANSFORMATION FOR HEAVILY SKEWED DATA</a></span></li><li><span><a href="#CUT-CONTINUOUS-VARIABLES-UP" data-toc-modified-id="CUT-CONTINUOUS-VARIABLES-UP-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>CUT CONTINUOUS VARIABLES UP</a></span></li><li><span><a href="#QUARTILES" data-toc-modified-id="QUARTILES-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>QUARTILES</a></span></li><li><span><a href="#BOXPLOT-WITH-VARYING-WIDTH" data-toc-modified-id="BOXPLOT-WITH-VARYING-WIDTH-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>BOXPLOT WITH VARYING WIDTH</a></span></li></ul></div>

# %% [markdown]
# ## TRANSFORMATION FOR HEAVILY SKEWED DATA

# %%
# Create movies_small
library(ggplot2)
library(ggplot2movies)
set.seed(123)
movies_small <- movies[sample(nrow(movies), 10000), ]
movies_small$rating <- factor(round(movies_small$rating))
# Out:
# Warning message:
# "package 'ggplot2movies' was built under R version 3.5.2"

# %%
head(movies_small)
# Out:
#   title                             year length budget rating votes r1   r2
# 1 Fair and Worm-er                  1946   7    NA     7       16    0.0 0.0
# 2 Shelf Life                        2000   4    NA     7       11    0.0 0.0
# 3 House: After Five Years of Living 1955  11    NA     6       15   14.5 0.0
# 4 Three Long Years                  2003  76    NA     8       11    4.5 0.0
# 5 Vidas Secas                       1963 103    NA     8      103    4.5 4.5
# 6 Anlian taohuayuan                 1992 107    NA     5       28    4.5 0.0
#   r3  r4  ... r9   r10  mpaa Action Animation Comedy Drama Documentary Romance
# 1 0.0 0.0 ...  0.0 14.5      0      1         1      0     0           0
# 2 0.0 0.0 ...  0.0 24.5      0      0         0      0     0           0
# 3 4.5 4.5 ...  0.0 14.5      0      0         0      0     1           0
# 4 4.5 0.0 ... 14.5 44.5      0      0         1      0     0           0
# 5 0.0 4.5 ... 14.5 44.5      0      0         0      1     0           0
# 6 4.5 4.5 ... 24.5 24.5      0      0         1      0     0           0
#   Short
# 1 1
# 2 1
# 3 1
# 4 0
# 5 0
# 6 0

# %%
# Add a boxplot geom
d <- ggplot(movies_small, aes(x = rating, y = votes)) +
  geom_point() +
  geom_boxplot() +
  stat_summary(fun.data = "mean_cl_normal",
               geom = "crossbar",
               width = 0.2,
               col = "red")

# Untransformed plot
d
# Out:
# plot without title

# %%
# Transform the scale = Log data points
d + scale_y_log10()
# Out:
# plot without title

# %%
# Transform the coordinates = log result stat, not data point
d + coord_trans(y = "log10")
# Out:
# plot without title

# %% [markdown]
# ## CUT CONTINUOUS VARIABLES UP

# %%
# Plot object p
p <- ggplot(diamonds, aes(x = carat, y = price))
p + geom_point(size = 0.01)
# Out:
# plot without title

# %%
# Use cut_interval
# 10 groups with equal range
p + geom_boxplot(aes(group = cut_interval(carat, n = 10)))
# Out:
# plot without title

# %%
# Use cut_number
# 10 groups with equal no of observations
p + geom_boxplot(aes(group = cut_number(carat, n = 10)))
# Out:
# plot without title

# %%
# Use cut_width
# Cut by width
p + geom_boxplot(aes(group = cut_width(carat, width = 0.25)))
# Out:
# plot without title

# %% [markdown]
# ## QUARTILES

# %%
# Function to plot 9 ways of calculating quartiles (not important)
plot_quart <- function(n) {
  set.seed(123)
  playData <- data.frame(raw.values = rnorm(n, 1, 6))
  
  quan.summary <- data.frame(t(sapply(1:9, function(x) quantile(playData$raw.values, type = x))))
  names(quan.summary) <- c("Min", "Q1", "Median", "Q3", "Max")
  quan.summary$Type <- as.factor(1:9)
  
  library(reshape2)
  quan.summary <- melt(quan.summary, id = "Type")
  quan.summary <- list(quartiles = quan.summary, values = playData)
  
  ggplot(quan.summary$quartiles, aes(x = Type, y = value, col = variable)) +
    geom_point() +
    geom_rug(data = quan.summary$values, aes(y = raw.values), sides = "l", inherit.aes = F)
}

# %%
plot_quart(4)
# Out:
# plot without title

# %%
plot_quart(100)
# Out:
# plot without title

# %% [markdown]
# =>The IQR becomes more consistent across methods as the sample size increases.

# %% [markdown]
# ## BOXPLOT WITH VARYING WIDTH

# %%
ggplot(diamonds, aes(x = cut, y = price, col = color)) +
  geom_boxplot(varwidth = T) +
  facet_grid(. ~ color)
# Out:
# plot without title
